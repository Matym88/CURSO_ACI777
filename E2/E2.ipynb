# %% [markdown]
# Matias monsalve 20/10/2021
#
# 1. Crear una carpeta nueva en su repositorio git con el nombre E2 (0.2 pto)
# 2. Dentro de E2 crear una carpeta que se llame data. (0.2 pto)
# 3. Guardar los datos asignados en esa carpeta. (0.2 pto)
# 4. Dentro de E2 debera crear un Jupyter Notebook llamado E2. (0.2 pto)
# 5. En el Jupyter Notebook, configurar la primera casilla en Lenguaje Markdown y escribir su nombre, fecha, y esta lista de instrucciones de forma ordenada. (0.2 pts)
# 6. Importar la librería pandas de python para poder procesar y graficar los datos del archivo. Utilizar describe, shape e indicar para que se utilizan estos comandos y que puede deducir de esta información. Debe separar el código en las casillas que estime conveniente, pero se solicita minimo que en una casilla esten solo las importaciones, en otra solo la lectura de los datos y otra con los plots, además cada casilla debe tener una casilla previa que -describa el código en formato markdown. (3 pts)
# 7. Hacer los gráficos correspondientes al conjunto de datos seleccionado. (1 pts)
# 8. Utilizar los comandos adecuados de git para actualizar su repositorio y dejarlo disponible en github de forma pública. (1 pts)

# %% [markdown]
# #importacion de todas las librerias a utilizar en este proyecto

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# lectura de archivo csv

# %%
datos=pd.read_csv('data/ejercicio.csv',index_col=0)
df=pd.DataFrame(datos)

# %% [markdown]
# describe nos sirve para informar sobre los datos estadisticos de nuestro dataframe
# esto nos sirve para visualizar nuestros percentiles, valores minimos, valores maximos, entre otros.

# %%
datos.describe()
# Out:
#        Codigo region     Poblacion  2020-04-01  2020-04-02  2020-04-03  \
# count      16.000000  1.600000e+01   16.000000   16.000000    16.00000
# mean        8.500000  1.216144e+06   10.812500   12.500000    14.81250
# std         4.760952  1.914966e+06   20.504369   22.238105    26.66638
# min         1.000000  1.072970e+05    0.000000    0.000000     0.00000
# 25%         4.750000  3.657570e+05    1.000000    1.000000     1.00000
# 50%         8.500000  7.639750e+05    4.000000    4.500000     4.00000
# 75%        12.250000  1.043742e+06   11.000000   13.250000    18.00000
# max        16.000000  8.125072e+06   83.000000   90.000000   107.00000
#
#        2020-04-04  2020-04-05  2020-04-06  2020-04-07  2020-04-08  ...  \
# count   16.000000   16.000000    16.00000   16.000000   16.000000  ...
# mean    17.500000   19.187500    20.43750   21.062500   22.625000  ...
# std     32.184883   36.133491    39.55413   39.260614   42.835927  ...
# min      0.000000    0.000000     0.00000    0.000000    0.000000  ...
# 25%      1.750000    1.750000     2.75000    2.000000    2.000000  ...
# 50%      4.000000    4.500000     5.50000    6.500000    7.000000  ...
# 75%     22.000000   23.000000    22.25000   21.750000   21.250000  ...
# max    129.000000  146.000000   161.00000  160.000000  174.000000  ...
#
#        2021-09-13  2021-09-14  2021-09-15  2021-09-16  2021-09-17  2021-09-18  \
# count   16.000000   16.000000   16.000000   16.000000   16.000000   16.000000
# mean    30.125000   30.062500   29.750000   28.937500   28.750000   27.812500
# std     78.075925   76.804921   75.265309   73.096711   71.554641   70.401912
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    4.000000    4.000000    4.000000    4.750000    4.750000
# 50%     10.500000   10.000000   10.000000    9.500000   10.000000    9.500000
# 75%     19.250000   19.250000   19.000000   19.250000   19.500000   16.000000
# max    321.000000  316.000000  310.000000  301.000000  295.000000  290.000000
#
#        2021-09-19  2021-09-20  2021-09-21  2021-09-22
# count   16.000000   16.000000   16.000000   16.000000
# mean    27.375000   27.125000   27.187500   26.812500
# std     69.169237   68.707957   68.416585   67.398535
# min      0.000000    1.000000    1.000000    1.000000
# 25%      4.500000    3.750000    3.750000    4.000000
# 50%      9.000000    9.000000    9.500000   10.000000
# 75%     15.250000   16.000000   16.000000   15.250000
# max    285.000000  283.000000  282.000000  278.000000
#
# [8 rows x 542 columns]

# %% [markdown]
# dataframe. shape nos sirve para poder visualizar cuantas filas y columnas tenemos en nuestro dataframe

# %%
datos.shape
# Out:
# (16, 542)

# %% [markdown]
# filtramos nuestros datos, eliminando todas las columnas que no nos sirven para realizar nuestro grafico

# %%
datos.drop(['Codigo region','Poblacion'], axis=1,inplace=True)

# %% [markdown]
# graficamos nuestro dataframe

# %%
datos.T.plot(figsize=(40,20), xlabel='FECHAS',ylabel='CASOS',title='PACIENTES UCI EN EL TIEMPO POR REGION')
# Out:
# <AxesSubplot:title={'center':'PACIENTES UCI EN EL TIEMPO POR REGION'}, xlabel='FECHAS', ylabel='CASOS'>

# %% [markdown]
# En la variable grafico2 guardamos la sumatoria de nuestros valores para posteriormente graficarlo

# %%
grafico2=datos.T.cumsum()
grafico2.plot(figsize=(40,20), xlabel='FECHAS',ylabel='CASOS',title='PACIENTES UCI AUMULADOS EN EL TIEMPO POR REGION ')
# Out:
# <AxesSubplot:title={'center':'PACIENTES UCI AUMULADOS EN EL TIEMPO POR REGION '}, xlabel='FECHAS', ylabel='CASOS'>
